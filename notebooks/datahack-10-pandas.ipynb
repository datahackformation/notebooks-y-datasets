# %% [markdown]
# # Datahack - pandas

# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.1.2'

# %% [markdown]
# # Dataframes, series y índices

# %% [markdown]
# ## Dataframes

# %%
pokemon = ["Bulbasaur", "Squirtle", "Charizard", "Pikachu", "Onix", "Geodude", "Vulpix", "Starmie"]
types = ["Grass Poison", "Water", "Fire Flying", "Electric", "Rock Ground",  "Rock Ground", "Fire", "Water"]
master = ["Ash", "Ash", "Ash", "Ash", "Brock", "Brock", "Misty", "Misty"]
pokedex_number = [1, 4, 7, 25, 95, 74, 37, 121]

# %%
pandas.DataFrame({'pokemon': pokemon,
                  'type': types,
                  'master': master,
                  'number': pokedex_number})
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
df_pokemon = pandas.DataFrame({'pokemon': pokemon,
                  'type': types,
                  'master': master,
                  'number': pokedex_number})

# %%
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
type(df_pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pokemon.values
# Out:
# array([['Bulbasaur', 'Grass Poison', 'Ash', 1],
#        ['Squirtle', 'Water', 'Ash', 4],
#        ['Charizard', 'Fire Flying', 'Ash', 7],
#        ['Pikachu', 'Electric', 'Ash', 25],
#        ['Onix', 'Rock Ground', 'Brock', 95],
#        ['Geodude', 'Rock Ground', 'Brock', 74],
#        ['Vulpix', 'Fire', 'Misty', 37],
#        ['Starmie', 'Water', 'Misty', 121]], dtype=object)

# %%
type(df_pokemon.values)
# Out:
# numpy.ndarray

# %%
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %% [markdown]
# ## Series

# %%
df_pokemon['pokemon']
# Out:
# 0    Bulbasaur
# 1     Squirtle
# 2    Charizard
# 3      Pikachu
# 4         Onix
# 5      Geodude
# 6       Vulpix
# 7      Starmie
# Name: pokemon, dtype: object

# %%
type(df_pokemon['pokemon'])
# Out:
# pandas.core.series.Series

# %%
df_pokemon['pokemon'].values
# Out:
# array(['Bulbasaur', 'Squirtle', 'Charizard', 'Pikachu', 'Onix', 'Geodude',
#        'Vulpix', 'Starmie'], dtype=object)

# %%
type(df_pokemon['pokemon'].values)
# Out:
# numpy.ndarray

# %%
df_pokemon['pokemon'].name
# Out:
# 'pokemon'

# %% [markdown]
# Las series son arreglos de numpy con un nombre, por lo que se le puede aplicar los métodos conocidos de numpy para obtener resultados

# %%
df_pokemon['number'].max()
# Out:
# 121

# %% [markdown]
# ## Columnas e Índices

# %%
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
df_pokemon.columns
# Out:
# Index(['pokemon', 'type', 'master', 'number'], dtype='object')

# %%
type(df_pokemon.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_pokemon.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
type(df_pokemon.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df_pokemon.loc[3, 'type']
# Out:
# 'Electric'

# %% [markdown]
# ## Agregar, reordenar y eliminar columnas

# %%
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
evolved = ["No", "No", "Yes", "No", "No", "No", "No", "Yes"]

# %%
df_pokemon['evolved'] = evolved

# %%
df_pokemon
# Out:
#      pokemon          type master  number evolved
# 0  Bulbasaur  Grass Poison    Ash       1      No
# 1   Squirtle         Water    Ash       4      No
# 2  Charizard   Fire Flying    Ash       7     Yes
# 3    Pikachu      Electric    Ash      25      No
# 4       Onix   Rock Ground  Brock      95      No
# 5    Geodude   Rock Ground  Brock      74      No
# 6     Vulpix          Fire  Misty      37      No
# 7    Starmie         Water  Misty     121     Yes

# %% [markdown]
# Broadcasting

# %%
df_pokemon['region'] = 'Kanto'

# %%
df_pokemon
# Out:
#      pokemon          type master  number evolved region
# 0  Bulbasaur  Grass Poison    Ash       1      No  Kanto
# 1   Squirtle         Water    Ash       4      No  Kanto
# 2  Charizard   Fire Flying    Ash       7     Yes  Kanto
# 3    Pikachu      Electric    Ash      25      No  Kanto
# 4       Onix   Rock Ground  Brock      95      No  Kanto
# 5    Geodude   Rock Ground  Brock      74      No  Kanto
# 6     Vulpix          Fire  Misty      37      No  Kanto
# 7    Starmie         Water  Misty     121     Yes  Kanto

# %%
df_pokemon.columns
# Out:
# Index(['pokemon', 'type', 'master', 'number', 'evolved', 'region'], dtype='object')

# %%
df_pokemon = df_pokemon[['region', 'pokemon', 'type', 'master', 'number', 'evolved']]
df_pokemon
# Out:
#   region    pokemon          type master  number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash       1      No
# 1  Kanto   Squirtle         Water    Ash       4      No
# 2  Kanto  Charizard   Fire Flying    Ash       7     Yes
# 3  Kanto    Pikachu      Electric    Ash      25      No
# 4  Kanto       Onix   Rock Ground  Brock      95      No
# 5  Kanto    Geodude   Rock Ground  Brock      74      No
# 6  Kanto     Vulpix          Fire  Misty      37      No
# 7  Kanto    Starmie         Water  Misty     121     Yes

# %%
df_pokemon[['pokemon', 'type']]
# Out:
#      pokemon          type
# 0  Bulbasaur  Grass Poison
# 1   Squirtle         Water
# 2  Charizard   Fire Flying
# 3    Pikachu      Electric
# 4       Onix   Rock Ground
# 5    Geodude   Rock Ground
# 6     Vulpix          Fire
# 7    Starmie         Water

# %%
df_pokemon[['pokemon', 'tipo']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-33c5ab6ebed3> in <module>()
# ----> 1 df_pokemon[['pokemon', 'tipo']]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['tipo'] not in index"

# %%
df_pokemon.get(['pokemon', 'type'])
# Out:
#      pokemon          type
# 0  Bulbasaur  Grass Poison
# 1   Squirtle         Water
# 2  Charizard   Fire Flying
# 3    Pikachu      Electric
# 4       Onix   Rock Ground
# 5    Geodude   Rock Ground
# 6     Vulpix          Fire
# 7    Starmie         Water

# %%
df_pokemon.get(['pokemon', 'tipo'])

# %%
df_pokemon
# Out:
#   region    pokemon          type master  number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash       1      No
# 1  Kanto   Squirtle         Water    Ash       4      No
# 2  Kanto  Charizard   Fire Flying    Ash       7     Yes
# 3  Kanto    Pikachu      Electric    Ash      25      No
# 4  Kanto       Onix   Rock Ground  Brock      95      No
# 5  Kanto    Geodude   Rock Ground  Brock      74      No
# 6  Kanto     Vulpix          Fire  Misty      37      No
# 7  Kanto    Starmie         Water  Misty     121     Yes

# %%
df_pokemon.drop('region', axis = 1)
# Out:
#      pokemon          type master  number evolved
# 0  Bulbasaur  Grass Poison    Ash       1      No
# 1   Squirtle         Water    Ash       4      No
# 2  Charizard   Fire Flying    Ash       7     Yes
# 3    Pikachu      Electric    Ash      25      No
# 4       Onix   Rock Ground  Brock      95      No
# 5    Geodude   Rock Ground  Brock      74      No
# 6     Vulpix          Fire  Misty      37      No
# 7    Starmie         Water  Misty     121     Yes

# %% [markdown]
# ## Agregar, eliminar filas

# %%
df_pokemon
# Out:
#   region    pokemon          type master  number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash       1      No
# 1  Kanto   Squirtle         Water    Ash       4      No
# 2  Kanto  Charizard   Fire Flying    Ash       7     Yes
# 3  Kanto    Pikachu      Electric    Ash      25      No
# 4  Kanto       Onix   Rock Ground  Brock      95      No
# 5  Kanto    Geodude   Rock Ground  Brock      74      No
# 6  Kanto     Vulpix          Fire  Misty      37      No
# 7  Kanto    Starmie         Water  Misty     121     Yes

# %%
nueva_fila = ["Johto", "Togepi", "Normal", "Misty", "", "No"]

# %%
df_pokemon.loc[8] = nueva_fila
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 1  Kanto   Squirtle         Water    Ash      4      No
# 2  Kanto  Charizard   Fire Flying    Ash      7     Yes
# 3  Kanto    Pikachu      Electric    Ash     25      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty             No

# %%
df_pokemon = df_pokemon.drop(2)
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 1  Kanto   Squirtle         Water    Ash      4      No
# 3  Kanto    Pikachu      Electric    Ash     25      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty             No

# %%
df_pokemon.loc[8, 'number'] = 175

# %%
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 1  Kanto   Squirtle         Water    Ash      4      No
# 3  Kanto    Pikachu      Electric    Ash     25      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty    175      No

# %% [markdown]
# ## Lectura de fuentes de datos

# %%
import pandas
import os

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.listdir('/content/drive/My Drive/datahack/notebooks/data')
# Out:
# ['world_cups.csv', 'world_cups.xlsx', 'pokedex.csv']

# %%
df_pokedex = pandas.read_csv('/content/drive/My Drive/datahack/notebooks/data/pokedex.csv')

# %%
df_pokedex
# Out:
#      pokedex_number        name   hp  ...  weight_kg  generation  is_legendary
# 0                 1   Bulbasaur   45  ...        6.9           1             0
# 1                 2     Ivysaur   60  ...       13.0           1             0
# 2                 3    Venusaur   80  ...      100.0           1             0
# 3                 4  Charmander   39  ...        8.5           1             0
# 4                 5  Charmeleon   58  ...       19.0           1             0
# ..              ...         ...  ...  ...        ...         ...           ...
# 796             797  Celesteela   97  ...      999.9           7             1
# 797             798     Kartana   59  ...        0.1           7             1
# 798             799    Guzzlord  223  ...      888.0           7             1
# 799             800    Necrozma   97  ...      230.0           7             1
# 800             801    Magearna   80  ...       80.5           7             1
#
# [801 rows x 14 columns]

# %%
df_mundiales = pandas.read_excel('/content/drive/My Drive/datahack/notebooks/data/world_cups.xlsx', sheet_name = 'players')

# %%
df_mundiales
# Out:
#        RoundID    MatchID Team Initials  ...       Player Name Position       Event
# 0          201       1096           FRA  ...       Alex THEPOT       GK         NaN
# 1          201       1096           MEX  ...   Oscar BONFIGLIO       GK         NaN
# 2          201       1096           FRA  ...  Marcel LANGILLER      NaN        G40'
# 3          201       1096           MEX  ...      Juan CARRENO      NaN        G70'
# 4          201       1096           FRA  ...   Ernest LIBERATI      NaN         NaN
# ...        ...        ...           ...  ...               ...      ...         ...
# 37779   255959  300186501           ARG  ...           ALVAREZ      NaN         NaN
# 37780   255959  300186501           GER  ...           KHEDIRA      NaN         NaN
# 37781   255959  300186501           ARG  ...            AGUERO      NaN  IH46' Y65'
# 37782   255959  300186501           GER  ...           MUSTAFI      NaN         NaN
# 37783   255959  300186501           ARG  ...           BASANTA      NaN         NaN
#
# [37784 rows x 9 columns]

# %% [markdown]
# ## Lectura de tablas de la web

# %% [markdown]
# Pokedex: https://pokemondb.net/pokedex/all

# %%
import requests

# %%
url = "https://pokemondb.net/pokedex/all"

html_text = requests.get(url).content

# %%
contenido = pandas.read_html(html_text)

# %%
type(contenido)
# Out:
# list

# %%
len(contenido)
# Out:
# 1

# %%
df_pokedex = contenido[0]

# %%
df_pokedex
# Out:
#         #                         Name            Type  ...  Sp. Atk  Sp. Def  Speed
# 0       1                    Bulbasaur    Grass Poison  ...       65       65     45
# 1       2                      Ivysaur    Grass Poison  ...       80       80     60
# 2       3                     Venusaur    Grass Poison  ...      100      100     80
# 3       3       Venusaur Mega Venusaur    Grass Poison  ...      122      120     80
# 4       4                   Charmander            Fire  ...       60       50     65
# ...   ...                          ...             ...  ...      ...      ...    ...
# 1029  890          Eternatus Eternamax   Poison Dragon  ...      125      250    130
# 1030  891                        Kubfu        Fighting  ...       53       50     72
# 1031  892  Urshifu Single Strike Style   Fighting Dark  ...       63       60     97
# 1032  892   Urshifu Rapid Strike Style  Fighting Water  ...       63       60     97
# 1033  893                       Zarude      Dark Grass  ...       70       95    105
#
# [1034 rows x 10 columns]

# %% [markdown]
# ## Exportar resultados

# %%
df_pokedex.head()
# Out:
#    #                    Name          Type  ...  Sp. Atk  Sp. Def  Speed
# 0  1               Bulbasaur  Grass Poison  ...       65       65     45
# 1  2                 Ivysaur  Grass Poison  ...       80       80     60
# 2  3                Venusaur  Grass Poison  ...      100      100     80
# 3  3  Venusaur Mega Venusaur  Grass Poison  ...      122      120     80
# 4  4              Charmander          Fire  ...       60       50     65
#
# [5 rows x 10 columns]

# %%
df_pokedex.to_csv('/content/drive/My Drive/datahack/notebooks/data/pokedex_web.csv')

# %% [markdown]
# ## Exploración

# %%
df_pokedex = pandas.read_csv('/content/drive/My Drive/datahack/notebooks/data/pokedex.csv')

# %%
df_pokedex.head(10)
# Out:
#    pokedex_number        name  hp  ...  weight_kg  generation  is_legendary
# 0               1   Bulbasaur  45  ...        6.9           1             0
# 1               2     Ivysaur  60  ...       13.0           1             0
# 2               3    Venusaur  80  ...      100.0           1             0
# 3               4  Charmander  39  ...        8.5           1             0
# 4               5  Charmeleon  58  ...       19.0           1             0
# 5               6   Charizard  78  ...       90.5           1             0
# 6               7    Squirtle  44  ...        9.0           1             0
# 7               8   Wartortle  59  ...       22.5           1             0
# 8               9   Blastoise  79  ...       85.5           1             0
# 9              10    Caterpie  45  ...        2.9           1             0
#
# [10 rows x 14 columns]

# %%
df_pokedex.shape
# Out:
# (801, 14)

# %%
df_pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pokedex_number  801 non-null    int64
#  1   name            801 non-null    object
#  2   hp              801 non-null    int64
#  3   attack          801 non-null    int64
#  4   defense         801 non-null    int64
#  5   sp_attack       801 non-null    int64
#  6   sp_defense      801 non-null    int64
#  7   speed           801 non-null    int64
#  8   type1           801 non-null    object
#  9   type2           417 non-null    object
#  10  height_m        781 non-null    float64
#  11  weight_kg       781 non-null    float64
#  12  generation      801 non-null    int64
#  13  is_legendary    801 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 87.7+ KB

# %%
df_pokedex.describe()
# Out:
#        pokedex_number          hp  ...  generation  is_legendary
# count      801.000000  801.000000  ...  801.000000    801.000000
# mean       401.000000   68.958801  ...    3.690387      0.087391
# std        231.373075   26.576015  ...    1.930420      0.282583
# min          1.000000    1.000000  ...    1.000000      0.000000
# 25%        201.000000   50.000000  ...    2.000000      0.000000
# 50%        401.000000   65.000000  ...    4.000000      0.000000
# 75%        601.000000   80.000000  ...    5.000000      0.000000
# max        801.000000  255.000000  ...    7.000000      1.000000
#
# [8 rows x 11 columns]

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  weight_kg  generation  is_legendary
# 0               1   Bulbasaur  45  ...        6.9           1             0
# 1               2     Ivysaur  60  ...       13.0           1             0
# 2               3    Venusaur  80  ...      100.0           1             0
# 3               4  Charmander  39  ...        8.5           1             0
# 4               5  Charmeleon  58  ...       19.0           1             0
#
# [5 rows x 14 columns]

# %%
df_pokedex['total_attack'] = df_pokedex['attack'] + df_pokedex['sp_attack']

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  generation  is_legendary  total_attack
# 0               1   Bulbasaur  45  ...           1             0           114
# 1               2     Ivysaur  60  ...           1             0           142
# 2               3    Venusaur  80  ...           1             0           222
# 3               4  Charmander  39  ...           1             0           112
# 4               5  Charmeleon  58  ...           1             0           144
#
# [5 rows x 15 columns]

# %%
df_pokedex.get(['hp', 'attack', 'defense',	'sp_attack', 'sp_defense', 'speed']).sum(axis = 1)
# Out:
# 0      318
# 1      405
# 2      625
# 3      309
# 4      405
#       ...
# 796    570
# 797    570
# 798    570
# 799    600
# 800    600
# Length: 801, dtype: int64

# %%
df_pokedex['total_stats'] = df_pokedex.get(['hp', 'attack', 'defense',	'sp_attack', 'sp_defense', 'speed']).sum(axis = 1)

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  is_legendary  total_attack  total_stats
# 0               1   Bulbasaur  45  ...             0           114          318
# 1               2     Ivysaur  60  ...             0           142          405
# 2               3    Venusaur  80  ...             0           222          625
# 3               4  Charmander  39  ...             0           112          309
# 4               5  Charmeleon  58  ...             0           144          405
#
# [5 rows x 16 columns]

# %% [markdown]
# ## apply

# %%
df_pokedex['generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
def generaciones(numero):
    if numero == 1:
        return 'Kanto'
    elif numero == 2:
        return 'Johto'
    elif numero == 3:
        return 'Hoenn'
    elif numero == 4:
        return 'Sinnoh'
    elif numero == 5:
        return 'Unova'
    elif numero == 6:
        return 'Kalos'
    elif numero == 7:
        return 'Alola'

# %%
df_pokedex['region'] = df_pokedex['generation'].apply(generaciones)

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_pokedex.tail()
# Out:
#      pokedex_number        name   hp  ...  total_attack  total_stats  region
# 796             797  Celesteela   97  ...           208          570   Alola
# 797             798     Kartana   59  ...           240          570   Alola
# 798             799    Guzzlord  223  ...           198          570   Alola
# 799             800    Necrozma   97  ...           234          600   Alola
# 800             801    Magearna   80  ...           225          600   Alola
#
# [5 rows x 17 columns]

# %% [markdown]
# ## filtros

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_pokedex.shape
# Out:
# (801, 17)

# %%
df_pokedex['is_legendary'] == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 796     True
# 797     True
# 798     True
# 799     True
# 800     True
# Name: is_legendary, Length: 801, dtype: bool

# %%
df_pokedex.loc[df_pokedex['is_legendary'] == 1]
# Out:
#      pokedex_number        name   hp  ...  total_attack  total_stats  region
# 143             144    Articuno   90  ...           180          580   Kanto
# 144             145      Zapdos   90  ...           215          580   Kanto
# 145             146     Moltres   90  ...           225          580   Kanto
# 149             150      Mewtwo  106  ...           344          780   Kanto
# 150             151         Mew  100  ...           200          600   Kanto
# ..              ...         ...  ...  ...           ...          ...     ...
# 796             797  Celesteela   97  ...           208          570   Alola
# 797             798     Kartana   59  ...           240          570   Alola
# 798             799    Guzzlord  223  ...           198          570   Alola
# 799             800    Necrozma   97  ...           234          600   Alola
# 800             801    Magearna   80  ...           225          600   Alola
#
# [70 rows x 17 columns]

# %%
import numpy

# %%
df_pokedex.loc[numpy.logical_and(df_pokedex['is_legendary'] == 1, df_pokedex['region'] == 'Johto')]
# Out:
#      pokedex_number     name   hp  ...  total_attack  total_stats  region
# 242             243   Raikou   90  ...           200          580   Johto
# 243             244    Entei  115  ...           205          580   Johto
# 244             245  Suicune  100  ...           165          580   Johto
# 248             249    Lugia  106  ...           180          680   Johto
# 249             250    Ho-Oh  106  ...           240          680   Johto
# 250             251   Celebi  100  ...           200          600   Johto
#
# [6 rows x 17 columns]

# %% [markdown]
# ## sort

# %%
df_kanto = df_pokedex.loc[df_pokedex['region'] == 'Kanto']
df_kanto.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_kanto.sort_values(by = 'total_stats')
# Out:
#      pokedex_number       name   hp  ...  total_attack  total_stats  region
# 12               13     Weedle   40  ...            55          195   Kanto
# 9                10   Caterpie   45  ...            50          195   Kanto
# 128             129   Magikarp   20  ...            25          200   Kanto
# 13               14     Kakuna   45  ...            50          205   Kanto
# 10               11    Metapod   50  ...            45          205   Kanto
# ..              ...        ...  ...  ...           ...          ...     ...
# 2                 3   Venusaur   80  ...           222          625   Kanto
# 8                 9  Blastoise   79  ...           238          630   Kanto
# 5                 6  Charizard   78  ...           263          634   Kanto
# 129             130   Gyarados   95  ...           225          640   Kanto
# 149             150     Mewtwo  106  ...           344          780   Kanto
#
# [151 rows x 17 columns]

# %%
df_kanto.sort_values(by = 'total_stats', ascending = False)
# Out:
#      pokedex_number       name   hp  ...  total_attack  total_stats  region
# 149             150     Mewtwo  106  ...           344          780   Kanto
# 129             130   Gyarados   95  ...           225          640   Kanto
# 5                 6  Charizard   78  ...           263          634   Kanto
# 8                 9  Blastoise   79  ...           238          630   Kanto
# 2                 3   Venusaur   80  ...           222          625   Kanto
# ..              ...        ...  ...  ...           ...          ...     ...
# 10               11    Metapod   50  ...            45          205   Kanto
# 13               14     Kakuna   45  ...            50          205   Kanto
# 128             129   Magikarp   20  ...            25          200   Kanto
# 9                10   Caterpie   45  ...            50          195   Kanto
# 12               13     Weedle   40  ...            55          195   Kanto
#
# [151 rows x 17 columns]

# %% [markdown]
# ## groupby

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_pokedex_group = df_pokedex.get(['region', 'name'])
df_pokedex_group.head()
# Out:
#   region        name
# 0  Kanto   Bulbasaur
# 1  Kanto     Ivysaur
# 2  Kanto    Venusaur
# 3  Kanto  Charmander
# 4  Kanto  Charmeleon

# %%
df_pokedex_group.tail()
# Out:
#     region        name
# 796  Alola  Celesteela
# 797  Alola     Kartana
# 798  Alola    Guzzlord
# 799  Alola    Necrozma
# 800  Alola    Magearna

# %%
df_pokedex_group.groupby('region').count()
# Out:
#         name
# region
# Alola     80
# Hoenn    135
# Johto    100
# Kalos     72
# Kanto    151
# Sinnoh   107
# Unova    156

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_pokedex.groupby('region').mean()
# Out:
#         pokedex_number         hp  ...  total_attack  total_stats
# region                             ...
# Alola            761.5  70.575000  ...    159.887500   448.162500
# Hoenn            319.0  65.666667  ...    148.748148   420.022222
# Johto            201.5  70.980000  ...    135.360000   413.180000
# Kalos            685.5  71.111111  ...    153.097222   437.611111
# Kanto             76.0  64.344371  ...    143.933775   416.251656
# Sinnoh           440.0  73.102804  ...    157.308411   451.177570
# Unova            571.5  70.314103  ...    150.532051   427.038462
#
# [7 rows x 13 columns]

# %%
df_pokedex.get(['is_legendary', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
                .groupby('is_legendary').mean()
# Out:
#                      hp      attack  ...  sp_defense      speed
# is_legendary                         ...
# 0             66.424077   74.841313  ...   67.945280  63.548564
# 1             95.428571  109.357143  ...  101.885714  95.428571
#
# [2 rows x 6 columns]

# %% [markdown]
# ## gráficos

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  ...  total_attack  total_stats  region
# 0               1   Bulbasaur  45  ...           114          318   Kanto
# 1               2     Ivysaur  60  ...           142          405   Kanto
# 2               3    Venusaur  80  ...           222          625   Kanto
# 3               4  Charmander  39  ...           112          309   Kanto
# 4               5  Charmeleon  58  ...           144          405   Kanto
#
# [5 rows x 17 columns]

# %%
df_pokedex.get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind = 'box')

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'grass', df_pokedex['type2'] == 'grass')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind = 'box')

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'fighting', df_pokedex['type2'] == 'fighting')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind = 'box')

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'fire', df_pokedex['type2'] == 'fire')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind = 'box')

# %%
df_pokedex['attack'].plot(kind = 'hist')
