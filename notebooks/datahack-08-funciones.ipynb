# %% [markdown]
# # Datahack - Funciones

# %% [markdown]
# ```
# def funcion (parametros):
#     bloque de codigo
# ```

# %%
list(range(1, 10, 2))
# Out:
# [1, 3, 5, 7, 9]

# %%
sum([1,2,23,4,5,6,6])
# Out:
# 47

# %% [markdown]
# ## creación de funciones

# %% [markdown]
# Definir una función que calcule el factorial de un número

# %%
def factorial(numero):
 
    producto = 1

    for n in range(1, numero + 1):
        producto = producto * n

    print(f"El factorial de {numero} es {producto}")

# %%
factorial(5)
# Out:
# El factorial de 5 es 120

# %%
factorial(6)
# Out:
# El factorial de 6 es 720

# %% [markdown]
# ## Variables locales y globales

# %%
a = 5

# %%
a
# Out:
# 5

# %%
producto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-84c7fcd4dd2e> in <module>()
# ----> 1 producto
#
# NameError: name 'producto' is not defined

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ab0680a89434> in <module>()
# ----> 1 n
#
# NameError: name 'n' is not defined

# %% [markdown]
# ## Valores de retorno

# %%
def factorial(numero):
 
    producto = 1

    for n in range(1, numero + 1):
        producto = producto * n

    return producto

# %%
factorial(5)
# Out:
# 120

# %%
fact_5 = factorial(5)

# %%
fact_5
# Out:
# 120

# %%
type(fact_5)
# Out:
# int

# %% [markdown]
# ## Valores de retorno: varios

# %%
def ratios(numero1, numero2):

    ratio1 = numero1 / numero2
    ratio2 = numero2 / numero1

    return ratio1, ratio2

# %%
ratios(4, 5)
# Out:
# (0.8, 1.25)

# %%
ratio1, ratio2 = ratios(4, 5)

# %%
ratio1
# Out:
# 0.8

# %%
ratio2
# Out:
# 1.25

# %%
ratio1, ratio2, ratio3  = ratios(4, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d06398c43f93> in <module>()
# ----> 1 ratio1, ratio2, ratio3  = ratios(4, 5)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# ## Valores de retorno: None

# %%
def sumar(numero1, numero2):
  
    resultado = numero1 + numero2
    return None

# %%
a = sumar(4, 6)

# %%
a

# %%
type(a)
# Out:
# NoneType

# %% [markdown]
# ## Ejemplo:
#
# Escribir una función que indique si un número es primo o no

# %%
def es_primo(numero):

    if numero == 2:
        return True

    elif numero % 2 == 0:
        return False

    else:
        for divisor in range(3, numero, 2):
            if numero % divisor == 0:
                return False
        
        return True

# %%
es_primo(2)
# Out:
# True

# %%
es_primo(6)
# Out:
# False

# %%
es_primo(15)
# Out:
# False

# %%
es_primo(17)
# Out:
# True

# %% [markdown]
# ## Ejercicio propuesto
#
# Crear un programa que reciba una lista de números y identifique si sus elementos son números primos.

# %%
def son_primos(lista_numeros):

    lista_primos = []

    for numero in lista_numeros:
        lista_primos.append(es_primo(numero))

    return lista_primos

# %%
son_primos([2, 6, 15, 17])
# Out:
# [True, False, False, True]

# %% [markdown]
# ## parámetros de una función

# %%
def potenciacion(base, exponente):
    return base ** exponente

# %%
potenciacion(2, 5)
# Out:
# 32

# %%
potenciacion(5, 2)
# Out:
# 25

# %%
potenciacion(base = 3, exponente = 5)
# Out:
# 243

# %%
potenciacion(exponente = 5, base = 3)
# Out:
# 243

# %% [markdown]
# ## parámetros con valores por defecto

# %%
def potenciacion(base, exponente = 2):
    return base ** exponente

# %%
potenciacion(5, 3)
# Out:
# 125

# %%
potenciacion(5)
# Out:
# 25

# %%
def potenciacion(base = 10, exponente):
    return base ** exponente
# Out:
#   File "<ipython-input-40-b6fb46817404>", line 1
#     def potenciacion(base = 10, exponente):
#                     ^
# SyntaxError: non-default argument follows default argument

# %%
def potenciacion(exponente, base = 10):
    return base ** exponente

# %%
potenciacion(2, 5)
# Out:
# 25

# %%
potenciacion(5)
# Out:
# 100000

# %% [markdown]
# ## *args

# %%
def suma_varios(num1, num2, num3):

    suma_total = num1 + num2 + num3
    return suma_total

# %%
suma_varios(3, 4, 5)
# Out:
# 12

# %%
suma_varios(2, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-18ade97dbc41> in <module>()
# ----> 1 suma_varios(2, 5)
#
# TypeError: suma_varios() missing 1 required positional argument: 'num3'

# %%
suma_varios(2,3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-33b068e6e505> in <module>()
# ----> 1 suma_varios(2,3,4,5)
#
# TypeError: suma_varios() takes 3 positional arguments but 4 were given

# %%
def suma_varios(*numeros):

    suma_total = 0

    for numero in numeros:
        suma_total = suma_total + numero

    return suma_total

# %%
suma_varios(2)
# Out:
# 2

# %%
suma_varios(3,4)
# Out:
# 7

# %%
suma_varios(1,2,3,4,5,6,7,8)
# Out:
# 36

# %% [markdown]
# ## **kwargs

# %%
def variables_parametros(**variables):
    print(variables)
    print(type(variables))

# %%
variables_parametros(nombre = "Manuel", puesto = "Data Scientist")
# Out:
# {'nombre': 'Manuel', 'puesto': 'Data Scientist'}
# <class 'dict'>

# %%
def caracteristicas(**variables):
    
    for key, value in variables.items():
        print(f"{key}: {value}")

# %%
caracteristicas(nombre = "Manuel", puesto = "Data Scientist")
# Out:
# nombre: Manuel
# puesto: Data Scientist

# %% [markdown]
# ## funciones lambda

# %%
def potenciacion(base, exponente):
    return base ** exponente

# %%
potenciacion_lambda = lambda base, exponente: base ** exponente

# %%
potenciacion_lambda(3, 4)
# Out:
# 81

# %%
potenciacion_lambda = lambda base, exponente = 2: base ** exponente

# %%
potenciacion_lambda(3, 4)
# Out:
# 81

# %%
potenciacion_lambda(3)
# Out:
# 9

# %% [markdown]
# ## comentarios en funciones

# %%
def potenciacion(base, exponente):
    """
    funcion que calcula la potenciacion de una base a un exponente

    params:

    base: int
    exponente: int
    """

    return base ** exponente

# %%
potenciacion(3, 5)
# Out:
# 243

# %% [markdown]
# ## map, filter, reduce

# %%
lista = [1,2,3,4,5]

[numero ** 2 for numero in lista]
# Out:
# [1, 4, 9, 16, 25]

# %%
elevar_cuadrado = lambda numero: numero ** 2

# %%
list(map(elevar_cuadrado, lista))
# Out:
# [1, 4, 9, 16, 25]

# %%
lista = list(range(1,101))

# %%
[numero for numero in lista if numero % 20 == 0]
# Out:
# [20, 40, 60, 80, 100]

# %%
filtro = lambda numero: numero % 20 == 0

# %%
list(filter(filtro, lista))
# Out:
# [20, 40, 60, 80, 100]

# %%
from functools import reduce 

lista = [1,2,3,4,5]

# %%
reductor = lambda a, b: a * b

# %%
reduce(reductor, lista)
# Out:
# 120

# %% [markdown]
# ## importar funciones de python

# %% [markdown]
# paquete random: https://docs.python.org/es/3/library/random.html

# %%
from random import shuffle

# %%
lista = [1,2,3,4,5,6]

shuffle(lista)

# %%
lista
# Out:
# [6, 4, 5, 2, 3, 1]

# %%
from random import randint

# %%
randint(10, 20)
# Out:
# 19

# %% [markdown]
# ## Ejercicio: Pangrams

# %% [markdown]
# paquete string: https://docs.python.org/es/3/library/string.html

# %% [markdown]
# "Farmer jack realized that big yellow quilts were expensive"
#
# "The quick brown fox jumps over the lazy dog"

# %%
import string

string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def es_pangram(frase):
    """devuelve True si la frase es un pangram 
    y False en caso no lo sea
    
    params:
    frase: str
    """

    alfabeto = string.ascii_lowercase

    frase = frase.lower()
    caracteres = list(set(frase))

    for caracter in alfabeto:
        if caracter not in caracteres:
            return False

    return True

# %%
es_pangram("Hola me llamo Manuel")
# Out:
# False

# %%
es_pangram("The quick brown fox jumps over the lazy dog")
# Out:
# True

# %% [markdown]
# ## Ejercicio: Números perfectos
#
# Definición de números perfectos https://es.wikipedia.org/wiki/Número_perfecto

# %%
def divisores_propios(numero):

    return [divisor for divisor in range(1, numero) if numero % divisor == 0]

# %%
divisores_propios(28)
# Out:
# [1, 2, 4, 7, 14]

# %%
def es_perfecto(numero):

    if numero == sum(divisores_propios(numero)):
        return True
    else:
        return False

# %%
es_perfecto(15)
# Out:
# False

# %%
es_perfecto(6)
# Out:
# True

# %%
es_perfecto(8128)
# Out:
# True
